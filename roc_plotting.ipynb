# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('seaborn-colorblind')
plt.style.use('ggplot')
# plt.style.use('seaborn-pastel')

# %%
# roc plots for all trainings start below

# %%
path = '/ocean/projects/phy210068p/hsu1/Training_results/DR3_lsr012/m12i/roc_parameters.hdf5'
with h5py.File(path, 'r') as f:
    print(f.keys())
    # a4o = f['4D_ep_a'][:]
    # i4o = f['4D_ep_i'][:]    
    # a5o = f['5D_ep_a'][:]
    # i5o = f['5D_ep_i'][:]
    a6o = f['6D_ep_a'][:]
    i6o = f['6D_ep_i'][:]
    a6ocyl = f['6D_cyl_ep_a'][:]
    i6ocyl = f['6D_cyl_ep_i'][:]
    a6ogal = f['6D_gal_ep_a'][:]
    i6ogal = f['6D_gal_ep_i'][:]
    a7o = f['7D_ep_a'][:]
    i7o = f['7D_ep_i'][:]
    a9o = f['9D_ep_a'][:]
    i9o = f['9D_ep_i'][:]
    a10o = f['10D_ep_a'][:]
    i10o = f['10D_ep_i'][:]
# Out:
# <KeysViewHDF5 ['10D_ep_a', '10D_ep_i', '6D_cyl_ep_a', '6D_cyl_ep_i', '6D_ep_a', '6D_ep_i', '6D_gal_ep_a', '6D_gal_ep_i', '7D_ep_a', '7D_ep_i', '9D_ep_a', '9D_ep_i']>

# %%
path = '/ocean/projects/phy210068p/hsu1/Training_results/DR3_lsr012/Gaia/roc_parameters.hdf5'
with h5py.File(path, 'r') as f:
    print(f.keys())
    a4 = f['4D_ep_a'][:]
    i4 = f['4D_ep_i'][:]    
    a5 = f['5D_ep_a'][:]
    i5 = f['5D_ep_i'][:]
    a6 = f['6D_ep_a'][:]
    i6 = f['6D_ep_i'][:]
    a6cyl = f['6D_cyl_ep_a'][:]
    i6cyl = f['6D_cyl_ep_i'][:]
    a6gal = f['6D_gal_ep_a'][:]
    i6gal = f['6D_gal_ep_i'][:]
    a7 = f['7D_ep_a'][:]
    i7 = f['7D_ep_i'][:]
    a9 = f['9D_ep_a'][:]
    i9 = f['9D_ep_i'][:]
    a10 = f['10D_ep_a'][:]
    i10 = f['10D_ep_i'][:]
# Out:
# <KeysViewHDF5 ['6D_cyl_ep_a', '6D_cyl_ep_i', '6D_ep_a', '6D_ep_i', '6D_gal_ep_a', '6D_gal_ep_i']>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /jet/home/hsu1/data/Gaiadr3_Accreted_Catalog/roc_plotting.ipynb Cell 4 line <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2262726964676573322e7073632e656475222c2275736572223a2268737531227d/jet/home/hsu1/data/Gaiadr3_Accreted_Catalog/roc_plotting.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> with h5py.File(path, 'r') as f:
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a2262726964676573322e7073632e656475222c2275736572223a2268737531227d/jet/home/hsu1/data/Gaiadr3_Accreted_Catalog/roc_plotting.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     print(f.keys())
# ...

# %%
fig, ax = plt.subplots(1, figsize = (10,10))

# ax.plot(i4o, a4o, linewidth=3, label='ra dec pmra pmdec')
# ax.plot(i5o, a5o, linewidth=3, label='ra dec pmra pmdec parallax')
ax.plot(i6o, a6o, linewidth=3, label='6D kinematics')
ax.plot(i6ocyl, a6ocyl, linewidth=3, label='6D cylindrical')
ax.plot(i6ogal, a6ogal, linewidth=3, label='6D galactocentric')
ax.plot(i7o, a7o, linewidth=3, label='6D kinematics + feh')
ax.plot(i9o, a9o, linewidth=3, label='6D kinematics + 3 actions')
ax.plot(i10o, a10o, linewidth=3, label='6D kinematics + 3 actions + feh')

# ax.plot(i4, a4, linewidth=3, linestyle='dashed')
# ax.plot(i5, a5, linewidth=3, linestyle='dashed', label='5D')
# ax.plot(i6, a6, linewidth=3, linestyle='dashed')
# ax.plot(i6cyl, a6cyl, linewidth=3, linestyle='dashed')
# ax.plot(i6gal, a6gal, linewidth=3, linestyle='dashed')
# ax.plot(i7, a7, linewidth=3, linestyle='dashed')
# ax.plot(i9, a9, linewidth=3, linestyle='dashed')
# ax.plot(i10, a10, linewidth=3, linestyle='dashed')

# ax.plot(0.045, 0.86, markersize=10, marker='D', label='V Selection')
# ax.plot(0.011, 0.862, markersize=10, marker='s', label='VM Selection')
ax.set_title('Model: DR3 (dashed:Gaia, solid: Ananke)', fontsize=20)
ax.set_xlabel(r'$\epsilon_I$', fontsize=35)
ax.set_ylabel(r'$\epsilon_A$', fontsize=35)
ax.set_xscale('log')
ax.tick_params(axis='both', labelsize=25)
ax.legend(fontsize=15, loc='lower right')
plt.xlim([0.004,1])
plt.ylim([0,1])
plt.show()

# %%
path = '/ocean/projects/phy210068p/hsu1/Training_results/DR2/m12i/roc_parameters.hdf5'
with h5py.File(path, 'r') as f:
    print(f.keys())
    a4o = f['4D_ep_a'][:]
    i4o = f['4D_ep_i'][:]    
    a5o = f['5D_ep_a'][:]
    i5o = f['5D_ep_i'][:]
    a6o = f['6D_ep_a'][:]
    i6o = f['6D_ep_i'][:]
    a7o = f['6+1D_ep_a'][:]
    i7o = f['6+1D_ep_i'][:]
    a9o = f['6D+Actions_ep_a'][:]
    i9o = f['6D+Actions_ep_i'][:]
    a10o = f['6+1D+Actions_ep_a'][:]
    i10o = f['6+1D+Actions_ep_i'][:]
    
# path2 = '/ocean/projects/phy210068p/hsu1/Training_results/DR2/m12iroc_parameters.hdf5'
# with h5py.File(path2,'r') as f:
#     print(f.keys())
#     a6a = f['6D_actions_ep_a'][:]
#     i6a = f['6D_actions_ep_i'][:]
# Out:
# <KeysViewHDF5 ['4D_ep_a', '4D_ep_a_inc_net', '4D_ep_i', '4D_ep_i_inc_net', '5D_ep_a', '5D_ep_a_inc_net', '5D_ep_i', '5D_ep_i_inc_net', '6+1D+Actions_ep_a', '6+1D+Actions_ep_i', '6+1D_ep_a', '6+1D_ep_i', '6D+Actions_ep_a', '6D+Actions_ep_i', '6D_Cartesian_ep_a', '6D_Cartesian_ep_i', '6D_Cylindrical_ep_a', '6D_Cylindrical_ep_i', '6D_ep_a', '6D_ep_i']>

# %%
path = '/ocean/projects/phy210068p/hsu1/Training_results/DR2_poe20/m12i/roc_parameters.hdf5'
with h5py.File(path, 'r') as f:
    print(f.keys())
    a4 = f['4D_ep_a'][:]
    i4 = f['4D_ep_i'][:]    
    a5 = f['5D_ep_a'][:]
    i5 = f['5D_ep_i'][:]
    a6 = f['6D_ep_a'][:]
    i6 = f['6D_ep_i'][:]
    a7 = f['7D_ep_a'][:]
    i7 = f['7D_ep_i'][:]
    a9 = f['9D_ep_a'][:]
    i9 = f['9D_ep_i'][:]
    a10 = f['10D_ep_a'][:]
    i10 = f['10D_ep_i'][:]
# Out:
# <KeysViewHDF5 ['10D_ep_a', '10D_ep_i', '4D_ep_a', '4D_ep_i', '5D_ep_a', '5D_ep_i', '6D_ep_a', '6D_ep_i', '7D_ep_a', '7D_ep_i', '9D_ep_a', '9D_ep_i']>

# %%
fig, ax = plt.subplots(1, figsize = (10,10))

ax.plot(i4, a4, linewidth=3, label='ra dec pmra pmdec')
ax.plot(i5, a5, linewidth=3, label='ra dec pmra pmdec parallax')
ax.plot(i6, a6, linewidth=3, label='6D kinematics')
ax.plot(i7, a7, linewidth=3, label='6D kinematics + feh')
ax.plot(i9, a9, linewidth=3, label='6D kinematics + 3 actions')
ax.plot(i10, a10, linewidth=3, label='6D kinematics + 3 actions + feh')
#ax.plot(i6a, a6a, linewidth=3, label='ra dec parallax + 3 actions', linestyle='dashed')

# ax.plot(0.045, 0.86, markersize=10, marker='D', label='V Selection')
# ax.plot(0.011, 0.862, markersize=10, marker='s', label='VM Selection')
ax.set_title('DR2 m12i poe>10', fontsize=20)
ax.set_xlabel(r'$\epsilon_I$', fontsize=35)
ax.set_ylabel(r'$\epsilon_A$', fontsize=35)
ax.set_xscale('log')
ax.tick_params(axis='both', labelsize=25)
ax.legend(fontsize=15, loc='lower right')
plt.xlim([0.004,1])
plt.ylim([0,1])
plt.show()

# %%
path = '/ocean/projects/phy210068p/hsu1/Training_results/DR3/m12i/roc_parameters.hdf5'
with h5py.File(path, 'r') as f:
    print(f.keys())
    a4 = f['4D_ep_a'][:]
    i4 = f['4D_ep_i'][:]    
    a5 = f['5D_ep_a'][:]
    i5 = f['5D_ep_i'][:]
    a6 = f['6D_ep_a'][:]
    i6 = f['6D_ep_i'][:]
    a7 = f['7D_ep_a'][:]
    i7 = f['7D_ep_i'][:]
    a9 = f['9D_ep_a'][:]
    i9 = f['9D_ep_i'][:]
    a10 = f['10D_ep_a'][:]
    i10 = f['10D_ep_i'][:]
# Out:
# <KeysViewHDF5 ['10D_ep_a', '10D_ep_i', '4D_ep_a', '4D_ep_i', '5D_ep_a', '5D_ep_i', '6D_ep_a', '6D_ep_i', '7D_ep_a', '7D_ep_i', '9D_ep_a', '9D_ep_i']>

# %%
fig, ax = plt.subplots(1, figsize = (10,10))

ax.plot(i4, a4, linewidth=3, label='4D kinematics')
# ax.plot(i5, a5, linewidth=3, label='ra dec pmra pmdec parallax')
ax.plot(i6, a6, linewidth=3, label='6D kinematics')
ax.plot(i7, a7, linewidth=3, label='6D kinematics + feh')
# ax.plot(i9, a9, linewidth=3, label='6D kinematics + 3 actions')
# ax.plot(i10, a10, linewidth=3, label='6D kinematics + 3 actions + feh')
#ax.plot(i6a, a6a, linewidth=3, label='ra dec parallax + 3 actions', linestyle='dashed')

# ax.plot(0.045, 0.86, markersize=10, marker='D', label='V Selection')
# ax.plot(0.011, 0.862, markersize=10, marker='s', label='VM Selection')
ax.set_title('DR3 m12i-lsr0 poe>10', fontsize=20)
ax.set_xlabel(r'$\epsilon_I$', fontsize=35)
ax.set_ylabel(r'$\epsilon_A$', fontsize=35)
ax.set_xscale('log')
ax.tick_params(axis='both', labelsize=25)
ax.legend(fontsize=15, loc='lower right')
plt.xlim([0.004,1])
plt.ylim([0,1])
plt.show()
